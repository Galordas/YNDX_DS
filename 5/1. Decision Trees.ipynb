# %% [markdown]
# ### 5.2. First model

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv(
    r'E:\COURSES\Кодинг\[Yandex praxis]. DS specialist + (2022)\5\02 Первая обученная модель\train_data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = pd.read_csv(
#       2     r'E:\COURSES\Кодинг\[Yandex praxis]. DS specialist + (2022)\5\02 Первая обученная модель\train_data.csv')
#
# ...

# %%
df.head(2)
# Out:
#    last_price  total_area  rooms  ceiling_height  floors_total  living_area  \
# 0   5400000.0        59.0      2            2.87           4.0         31.5
# 1  13200000.0       109.0      4            3.15           5.0         72.0
#
#    floor  is_apartment  studio  open_plan  kitchen_area  balcony  \
# 0      2           0.0     0.0        0.0           6.6      0.0
# 1      2           0.0     0.0        0.0          12.2      0.0
#
#    airports_nearest  cityCenters_nearest
# 0           20485.0               8180.0
# 1           42683.0               8643.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6495 entries, 0 to 6494
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   last_price           6495 non-null   float64
#  1   total_area           6495 non-null   float64
#  2   rooms                6495 non-null   int64
#  3   ceiling_height       6495 non-null   float64
#  4   floors_total         6495 non-null   float64
#  5   living_area          6495 non-null   float64
#  6   floor                6495 non-null   int64
#  7   is_apartment         6495 non-null   float64
#  8   studio               6495 non-null   float64
#  9   open_plan            6495 non-null   float64
#  10  kitchen_area         6495 non-null   float64
#  11  balcony              6495 non-null   float64
#  12  airports_nearest     6495 non-null   float64
#  13  cityCenters_nearest  6495 non-null   float64
# dtypes: float64(12), int64(2)
# memory usage: 710.5 KB

# %%
df.last_price.median()
# Out:
# 5650000.0

# %%
df['price_class'] = 0
df.loc[df['last_price'] > df.last_price.median(), 'price_class'] = 1

# %%
df[['price_class', 'last_price']].head(2)
# Out:
#    price_class  last_price
# 0            0   5400000.0
# 1            1  13200000.0

# %%
features = df.drop(['price_class', 'last_price'], axis=1)
target = df['price_class']
print(features.shape)
print(target.shape)
# Out:
# (6495, 13)
# (6495,)

# %% [markdown]
# Каждой модели в sklearn соответствует отдельная структура данных. `DecisionTreeClassifier` (англ. «классификатор дерева решений») — это структура данных для классификации деревом решений.
#
# Обучение выполняется методом `fit()`, а предсказание — `predict()`.
# Модель сохранена в переменной model. Она и обучается, и предсказывае

# %%
model = DecisionTreeClassifier()

# %%
model.fit(features, target)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# Теперь в переменной `model` полноценная модель. Чтобы предсказать ответы, нужно вызвать метод `predict()` (англ. «предсказать») и передать ему таблицу с признаками новых объектов.

# %%
new_features = pd.DataFrame({
    'total_area': [900, 109],
    'rooms': [12, 2],
    'ceiling_height': [2.80, 2.75],
    'floors_total': [25, 25],
    'living_area': [409.7, 32],
    'floor': [25, 25],
    'is_apartment': [0, 0],
    'studio': [0, 0],
    'open_plan': [0, 0],
    'kitchen_area': [112, 40.5],
    'balcony': [0, 0],
    'airports_nearest': [30706.0, 36421.0],
    'cityCenters_nearest': [7877.0, 9176.0]
}
)

# %%
answers = model.predict(new_features)
answers
# Out:
# array([1, 0], dtype=int64)

# %% [markdown]
# #### 5.4. Model quality

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv(
    r'E:\COURSES\Кодинг\[Yandex praxis]. DS specialist + (2022)\5\02 Первая обученная модель\train_data.csv')

df.loc[df['last_price'] > 5650000, 'price_class'] = 1
df.loc[df['last_price'] <= 5650000, 'price_class'] = 0

features = df.drop(['price_class', 'last_price'], axis=1)
target = df['price_class']

model = DecisionTreeClassifier(random_state=12345)

model.fit(features, target)
# Out:
# DecisionTreeClassifier(random_state=12345)

# %%
test_dataset = (
    pd.read_csv(
        r'E:\COURSES\Кодинг\[Yandex praxis]. DS specialist + (2022)\5\03 Качество модели\test_data.csv',
        nrows=3)
)

test_predictions = (model.predict
    (test_dataset
    .drop(['Unnamed: 0', 'last_price'], axis=1))
                    )
test_dataset['price_class'] = 0
test_dataset.loc[test_dataset['last_price'] > 5600000, 'price_class'] = 1
print(f'Правильный ответ {list(test_dataset['price_class'])} ')
print(f'Предсказание модели {test_predictions}')
# Out:
# Правильный ответ [0, 1, 0]
# Предсказание модели [0. 0. 1.]

# %% [markdown]
# Трёх примеров недостаточно, чтобы понять, хорошо или плохо работает модель. Посчитайте количество ошибок модели на всей тестовой выборке.
# Напишите функцию `error_count()`(англ. «подсчёт ошибок»), которая:
# Принимает на вход правильные ответы и предсказания модели.
# Сравнивает их в цикле `for`.
# Возвращает количество расхождений между ними.
# Выведите результат работы `error_count()` с тестовым набором в таком формате (уже сделано в прекоде):

# %%
df = pd.read_csv(r'E:\COURSES\Кодинг\[Yandex praxis]. DS specialist + (2022)\5\02 Первая обученная модель\train_data.csv')

df.loc[df['last_price'] > 5650000, 'price_class'] = 1
df.loc[df['last_price'] <= 5650000, 'price_class'] = 0

features = df.drop(['last_price', 'price_class'], axis=1)
target = df['price_class']
model = DecisionTreeClassifier(random_state=12345)
model.fit(features, target)

test_df = pd.read_csv(r'E:\COURSES\Кодинг\[Yandex praxis]. DS specialist + (2022)\5\03 Качество модели\test_data.csv')
test_df.loc[test_df['last_price'] > 5650000, 'price_class'] = 1
test_df.loc[test_df['last_price'] <= 5650000, 'price_class'] = 0

test_features = test_df.drop(['last_price', 'price_class'], axis=1)

test_predictions = (model.predict(test_features
                                  .drop(
    ['Unnamed: 0'], axis=1)))

def error_count(answers, predictions):
    error_counter = 0
    for i in range(len(predictions)):
        if answers.loc[i,'price_class'] != predictions[i]:
            error_counter += 1
    return error_counter
#
print("Ошибок:", error_count(test_df, test_predictions))
accuracy = (len(test_predictions)-error_count(test_df, test_predictions))/len(test_predictions)
print(accuracy)
# Out:
# Ошибок: 91
# 0.8595679012345679

# %% [markdown]
# #### 5.5. Accuracy metrics

# %%
from sklearn.metrics import accuracy_score
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

df = pd.read_csv(r'E:\COURSES\Кодинг\[Yandex praxis]. DS specialist + (2022)\5\02 Первая обученная модель\train_data.csv')

df.loc[df['last_price'] > 5650000, 'price_class'] = 1
df.loc[df['last_price'] <= 5650000, 'price_class'] = 0

features = df.drop(['last_price', 'price_class'], axis=1)
target = df['price_class']
model = DecisionTreeClassifier(random_state=12345)
model.fit(features, target)
test_df = pd.read_csv(r'E:\COURSES\Кодинг\[Yandex praxis]. DS specialist + (2022)\5\03 Качество модели\test_data.csv')

test_df.loc[test_df['last_price'] > 5650000, 'price_class'] = 1
test_df.loc[test_df['last_price'] <= 5650000, 'price_class'] = 0
test_features = test_df.drop(['last_price', 'price_class'], axis=1)
test_predictions = (model.predict(test_features
.drop(
    ['Unnamed: 0'], axis=1)))
test_target = test_df['price_class']


def error_count(answers, predictions):
    error_counter = 0
    for i in range(len(predictions)):
        if answers.loc[i,'price_class'] != predictions[i]:
            error_counter += 1
    return error_counter

# < напишите здесь код расчёта на обучающей выборке >
# < напишите здесь код расчёта на тестовой выборке >
train_predictions = model.predict(features)
train_set_accuracy = accuracy_score(target, train_predictions)

test_set_accuracy = accuracy_score(test_target, test_predictions)
print("Accuracy")
print("Обучающая выборка:", train_set_accuracy)
print("Тестовая выборка:" ,test_set_accuracy)
# Out:
# Accuracy
# Обучающая выборка: 0.9998460354118552
# Тестовая выборка: 0.8595679012345679

# %% [markdown]
# #### 5.6. Overfitting and underfitting in machine learning

# %% [markdown]
# Обнаружили, что accuracy на тестовой выборке модели ниже, чем на обучающей? В машинном обучении такое встречается часто. Почему?
# Модель хорошо объясняла примеры из обучающего набора данных, но запуталась в тестовой выборке и не смогла ответить правильно? Вы столкнулись с проблемой `переобучения`.
#
# Такое бывает у всех. Представьте: чтобы подготовиться к экзамену, вы решаете прошлогодние задачи. Стараетесь, доводите до автоматизма, выполняете одно и то же задание по нескольку раз. А на экзамене вам достаётся задача, которую ни разу не решали. К такому повороту вы не были готовы и получили низкую оценку. Как и ваша модель сейчас.
# Обратный эффект — `недообучение`. Оно возникает, когда качество на обучающей и тестовой выборках примерно одинаковое, причём низкое. Эх, не удалось перед экзаменом не то, что ответы зазубрить, а вообще билеты дочитать. Знакомая история?
#
# `Переобучение` означает, что модель плохо поняла зависимости в данных.
#
# `Глубина дерева` (высота дерева) — это максимальное количество условий от «вершины» до финального ответа. Считается по количеству переходов между узлами.
# Если дерево высокое, у модели склонность к переобучению; низкое — к недообучению.
#
# Глубина дерева в `sklearn` задаётся параметром `max_depth` (англ. «максимальная глубина»):
#
# `model = DecisionTreeClassifier(random_state=12345, max_depth=3)`

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

df = pd.read_csv(r'C:\Users\Alex\Desktop\5\02 Первая обученная модель\train_data.csv')
df.loc[df['last_price'] > 5650000, 'price_class'] = 1
df.loc[df['last_price'] <= 5650000, 'price_class'] = 0

features = df.drop(['last_price', 'price_class'], axis=1)
target = df['price_class']

best_model = None
best_result = 0
results = []
for depth in range(1, 6):
    model = DecisionTreeClassifier(random_state=12345, max_depth=depth)  # обучите модель с заданной глубиной дерева
    model.fit(features, target)  # обучите модель
    predictions = model.predict(features)  # получите предсказания модели
    result = accuracy_score(target, predictions)  # посчитайте качество модели
    results.append(result)
    if result > best_result:
        best_model = model
        best_result = result
        best_depth = depth
print("Accuracy лучшей модели:", best_result, ', depth = ', depth)
print(results)
# Out:
# Accuracy лучшей модели: 0.891301000769823 , depth =  5
# [0.8435719784449577, 0.8435719784449577, 0.8665127020785219, 0.8739030023094688, 0.891301000769823]

# %% [markdown]
# #### 5.6. Validation set
#
# * Доступен исходный датасет, а тестовая выборка спрятана. Тогда рекомендуется 75% данных отвести под обучающую, а 25% — под валидационную. Соотношение 3:1. Этот сценарий используется в задачах нашего тренажёр
# * Спрятанной тестовой выборки нет. Значит, данные нужно разбить на три части: обучающую, валидационную и тестовую. Размеры тестового и валидационного наборов обычно равны. Исходные данные разбивают в соотношении 3:1:1.
#
# In `sklearn` module there is a method called `train_test_split` which splits a dataset into parts and has the following functions:
# * df to be splitted
# * test_size = (0-1)
# * random state

# %% [markdown]
# ##### Work

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

df = pd.read_csv(r'C:\Users\Alex\Desktop\5\02 Первая обученная модель\train_data.csv')
df.loc[df['last_price'] > 5650000, 'price_class'] = 1
df.loc[df['last_price'] <= 5650000, 'price_class'] = 0

df_train, df_valid = train_test_split(df, test_size = 0.25, random_state = 333)


features_train = df_train.drop(['last_price', 'price_class'], axis=1)
target_train = df_train['price_class']

features_valid = df_valid.drop(['last_price', 'price_class'], axis=1)
target_valid = df_valid['price_class']

print(features_train.shape)
print(target_train.shape)
print(features_valid.shape)
print(target_valid.shape)
# Out:
# (4871, 13)
# (4871,)
# (1624, 13)
# (1624,)

# %% [markdown]
# #### Hyperparameters
#
# Что определяет правильность предсказания решающего дерева? Количество узлов и их взаимное расположение (структура), вопрос в вершине и ответы в нижних узлах. Всё это `параметры`, которые модель узнаёт из обучающих данных.
#
# Помимо обычных параметров, есть ещё `гиперпараметры`, настройки алгоритмов обучения. В решающем дереве, например, это максимальная глубина или выбор критерия — Джини либо энтропийного (о нём расскажем позже). Гиперпараметры помогают улучшить модель. Изменить их можно до начала обучения. Значения гиперпараметров установлены по умолчанию.
#
# Hyperparameters for `decision trees`:
#
# * `max_depth` The maximum depth of the tree
# * `min_samples_split` (от англ. «минимальное количество примеров для разделения»). Этот гиперпараметр запрещает создавать узлы, в которые попадает слишком мало объектов обучающей выборки.
#
# * `min_samples_leaf` (от англ. «минимальное количество объектов в листе»). Листья — это нижние узлы с ответами. А гиперпараметр не разрешает создавать лист, в котором слишком мало объектов обучающей выборки.

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

df = pd.read_csv(r'C:\Users\Alex\Desktop\5\02 Первая обученная модель\train_data.csv')
df.loc[df['last_price'] > 5650000, 'price_class'] = 1
df.loc[df['last_price'] <= 5650000, 'price_class'] = 0
df_train, df_valid = train_test_split(df, test_size=0.25, random_state=12345)

features_train = df_train.drop(['last_price', 'price_class'], axis=1)
target_train = df_train['price_class']
features_valid = df_valid.drop(['last_price', 'price_class'], axis=1)
target_valid = df_valid['price_class']

for depth in range(1,6):
    model = DecisionTreeClassifier(random_state=333, max_depth=depth)
    model.fit(features_train, target_train)
    predictions_valid = model.predict(features_valid)
    result = accuracy_score(target_valid, predictions_valid)
    print('max_depth =', depth, ':', result)
# Out:
# max_depth = 1 : 0.8522167487684729
# max_depth = 2 : 0.8522167487684729
# max_depth = 3 : 0.8466748768472906
# max_depth = 4 : 0.8725369458128078
# max_depth = 5 : 0.8663793103448276
